# %% [markdown]
# ## Author merging notebook

# %% [markdown]
# This notebook was used to check the quality of matches generated with mag_matching.ipynb
# Matches were generated (mainly) based on DOIs, title and year. The minimum additional requirement was for one author to be found in both entries. This notebbok checks whether this has lead to accidental incorrect matches.

# %%
from glob import glob
from json import loads, dump, load
from os.path import basename, exists, isfile, isdir, sep
from os import makedirs, listdir, getcwd
from datetime import datetime
import pandas as pd

# %% [markdown]
# Set input paths for the CORE and MAG set and load a list of all matches created by the mag_matching.ipynb notebook.

# %%
mag_path = "mag_sets/mag_in_core"
core_path = "core_sets/mag_matched/2021_04_09_12_08_34/batches"
mlist = load(open("results/mag_match/matches.json","r"))['matches']
if isdir(core_path):
    core_filepaths = sorted(glob(core_path + sep + "*"))

# %% [markdown]
# Define a function to load id, title and authors from all matched anetries. Start spark context, then apply the function to all matched entries and store results in separate lists

# %%
def id_auth(line):
    j = loads(line)
    if 'id' in j:
        return (j['id'],j['authors'],j['title'])
    else:
        return (j['coreId'],j['authors'],j['title'])

# %%
from pyspark import SparkContext
sc = SparkContext(master = 'local[8]')

# %%
print(datetime.now())
mag_auth = []
with open(mag_path) as f:
    for i,line in enumerate(f):
        if i%1000000 == 0:
            print(i,": ",datetime.now())
        mag_auth.append(id_auth(line))
print(datetime.now())
# Out:
# 2021-04-12 12:40:07.937312
# 0 :  2021-04-12 12:40:07.961380
# 1000000 :  2021-04-12 12:40:31.613487
# 2000000 :  2021-04-12 12:41:00.158131
# 3000000 :  2021-04-12 12:41:28.512934
# 2021-04-12 12:41:41.564202

# %%
print(datetime.now())
core_auth = []
for path in core_filepaths:
    print(basename(path))
    rdd = sc.textFile(f"file://{getcwd()}/{path}")
    data = rdd.map(lambda line: id_auth(line))
    core_auth = core_auth + data.collect()
    print(datetime.now())
# Out:
# 2021-04-12 12:41:46.448253
# 001
# 2021-04-12 12:41:58.727182
# 002
# 2021-04-12 12:42:04.537347
# 003
# 2021-04-12 12:42:12.322149
# 004
# 2021-04-12 12:42:22.204538
# 005
# 2021-04-12 12:42:27.988688
# 006
# 2021-04-12 12:42:45.112159
# 007
# 2021-04-12 12:42:57.964316
# 008
# 2021-04-12 12:42:58.785696
# 009
# 2021-04-12 12:42:59.509462
# 010
# 2021-04-12 12:43:10.531643
# 011
# 2021-04-12 12:43:27.629680
# 012
# 2021-04-12 12:43:40.925310
# 013
# 2021-04-12 12:43:58.820433
# 014
# 2021-04-12 12:44:23.308718
# 015
# 2021-04-12 12:44:31.234184
# 016
# 2021-04-12 12:44:35.544872
# 017
# 2021-04-12 12:44:55.607287
# 018
# 2021-04-12 12:45:05.365178
# 019
# 2021-04-12 12:45:20.854344
# 020
# 2021-04-12 12:45:21.099376
# 021
# 2021-04-12 12:45:42.881556
# 022
# 2021-04-12 12:45:54.428403
# 023
# 2021-04-12 12:46:22.552479
# 024
# 2021-04-12 12:46:27.118037
# 025
# 2021-04-12 12:46:45.492848
# 026
# 2021-04-12 12:46:46.807423
# 027
# 2021-04-12 12:46:55.743782
# 028
# 2021-04-12 12:47:02.748067
# 029
# 2021-04-12 12:48:03.185817
# 031
# 2021-04-12 12:48:10.855187
# 032
# 2021-04-12 12:48:27.103498
# 033
# 2021-04-12 12:48:47.197146
# 034
# 2021-04-12 12:49:20.690415
# 035
# 2021-04-12 12:49:38.797471
# 036
# 2021-04-12 12:49:59.598393
# 037
# 2021-04-12 12:50:11.160848
# 038
# 2021-04-12 12:50:22.787641
# 039
# 2021-04-12 12:50:34.432652
# 040
# 2021-04-12 12:50:45.982671
# 041
# 2021-04-12 12:50:57.434500
# 042
# 2021-04-12 12:51:08.892731
# 043
# 2021-04-12 12:51:20.546488
# 044
# 2021-04-12 12:51:32.161955
# 045
# 2021-04-12 12:51:43.858549
# 046
# 2021-04-12 12:51:55.442284
# 047
# 2021-04-12 12:52:07.138500
# 048
# 2021-04-12 12:52:18.611546
# 049
# 2021-04-12 12:52:30.232443
# 050
# 2021-04-12 12:52:41.894823
# 051
# 2021-04-12 12:52:54.270419
# 052
# 2021-04-12 12:53:06.106548
# 053
# 2021-04-12 12:53:18.004219
# 054
# 2021-04-12 12:53:30.018847
# 055
# 2021-04-12 12:53:41.546697
# 056
# 2021-04-12 12:53:45.965444
# 057
# 2021-04-12 12:53:48.539399
# 058
# 2021-04-12 12:53:49.949690
# 059
# 2021-04-12 12:53:50.472224
# 060
# 2021-04-12 12:53:51.002737
# 061
# 2021-04-12 12:53:51.442695
# 062
# 2021-04-12 12:53:52.215809
# 063
# 2021-04-12 12:53:53.329091
# 064
# 2021-04-12 12:53:53.553825
# 065
# 2021-04-12 12:53:55.587763
# 066
# 2021-04-12 12:54:17.922992
# 067
# 2021-04-12 12:54:34.796003
# 068
# 2021-04-12 12:54:58.924279
# 069
# 2021-04-12 12:55:23.097155
# 070
# 2021-04-12 12:55:44.786648
# 071
# 2021-04-12 12:55:46.446528
# 072
# 2021-04-12 12:55:57.874216
# 073
# 2021-04-12 12:56:05.991029
# 074
# 2021-04-12 12:56:09.398985
# 075
# 2021-04-12 12:56:16.149740
# 076
# 2021-04-12 12:56:26.809035
# 077
# 2021-04-12 12:56:47.455503
# 078
# 2021-04-12 12:56:52.297235
# 079
# 2021-04-12 12:56:56.213397
# 080
# 2021-04-12 12:56:59.389855
# 081
# 2021-04-12 12:57:03.314559
# 082
# 2021-04-12 12:57:17.774381
# 083
# 2021-04-12 12:57:31.800979
# 084
# 2021-04-12 12:57:36.255246
# 085
# 2021-04-12 12:57:50.253481
# 086
# 2021-04-12 12:57:59.579998
# 087
# 2021-04-12 12:58:09.934321
# 088
# 2021-04-12 12:58:12.217580
# 089
# 2021-04-12 12:58:17.947847
# 090
# 2021-04-12 12:58:22.431829
# 091
# 2021-04-12 12:58:41.684341
# 092
# 2021-04-12 12:59:20.863319
# 093
# 2021-04-12 12:59:32.029784
# 094
# 2021-04-12 12:59:43.298566
# 095
# 2021-04-12 12:59:59.240022
# 096
# 2021-04-12 13:00:16.974549
# 097
# 2021-04-12 13:00:30.215453
# 098
# 2021-04-12 13:00:33.141397
# 099
# 2021-04-12 13:00:43.753610
# 100
# 2021-04-12 13:00:56.666183
# 101
# 2021-04-12 13:01:04.432123
# 102
# 2021-04-12 13:01:10.876741
# 103
# 2021-04-12 13:01:18.297767
# 104
# 2021-04-12 13:01:25.717391
# 105
# 2021-04-12 13:01:30.778133
# 106
# 2021-04-12 13:01:40.669533
# 107
# 2021-04-12 13:01:46.078292
# 108
# 2021-04-12 13:01:51.097436
# 109
# 2021-04-12 13:01:59.499974
# 110
# 2021-04-12 13:02:14.346910
# 111
# 2021-04-12 13:02:32.480648
# 112
# 2021-04-12 13:03:07.482565
# 113
# 2021-04-12 13:03:17.905361
# 114
# 2021-04-12 13:03:20.814815
# 115
# 2021-04-12 13:03:32.291109
# 116
# 2021-04-12 13:03:36.213706
# 117
# 2021-04-12 13:03:47.126684
# 118
# 2021-04-12 13:03:55.137732
# 119
# 2021-04-12 13:04:11.553310
# 120
# 2021-04-12 13:04:20.503055
# 121
# 2021-04-12 13:04:30.747812
# 122
# 2021-04-12 13:04:55.098068
# 123
# 2021-04-12 13:05:03.089081
# 124
# 2021-04-12 13:05:27.333598
# 125
# 2021-04-12 13:05:49.640771
# 126
# 2021-04-12 13:06:03.479622
# 127
# 2021-04-12 13:06:18.290120
# 128
# 2021-04-12 13:06:31.758871
# 129
# 2021-04-12 13:06:45.563456
# 130
# 2021-04-12 13:06:58.961312
# 131
# 2021-04-12 13:07:12.259443
# 132
# 2021-04-12 13:07:25.430603
# 133
# 2021-04-12 13:07:38.538791
# 134
# 2021-04-12 13:07:51.023413
# 135
# 2021-04-12 13:08:03.354495
# 136
# 2021-04-12 13:08:14.345262
# 137
# 2021-04-12 13:08:19.902046
# 138
# 2021-04-12 13:08:36.703910
# 139
# 2021-04-12 13:08:54.889670
# 140
# 2021-04-12 13:09:11.553595
# 141
# 2021-04-12 13:09:38.334242
# 142
# 2021-04-12 13:09:54.960978
# 143
# 2021-04-12 13:10:11.755711
# 144
# 2021-04-12 13:10:28.484085
# 145
# 2021-04-12 13:10:45.057623
# 146
# 2021-04-12 13:11:01.082093
# 147
# 2021-04-12 13:11:07.317744
# 148
# 2021-04-12 13:11:38.650271
# 149
# 2021-04-12 13:11:50.752256
# 150
# 2021-04-12 13:11:53.901006
# 151
# 2021-04-12 13:12:21.825531
# 152
# 2021-04-12 13:12:30.081795
# 153
# 2021-04-12 13:12:37.888747
# 154
# 2021-04-12 13:13:12.602280
# 155
# 2021-04-12 13:13:19.345266
# 156
# 2021-04-12 13:13:33.877842
# 157
# 2021-04-12 13:13:44.097161
# 158
# 2021-04-12 13:13:47.753036
# 159
# 2021-04-12 13:13:48.537440
# 160
# 2021-04-12 13:13:53.400322
# 161
# 2021-04-12 13:14:04.946045
# 162
# 2021-04-12 13:14:08.830179
# 163
# 2021-04-12 13:14:16.212689
# 164
# 2021-04-12 13:14:38.360123
# 165
# 2021-04-12 13:14:53.153948
# 166
# 2021-04-12 13:15:01.229034
# 167
# 2021-04-12 13:15:14.012926
# 168
# 2021-04-12 13:15:22.072602
# 169
# 2021-04-12 13:15:32.405084
# 170
# 2021-04-12 13:15:40.663768
# 171
# 2021-04-12 13:15:48.045445
# 172
# 2021-04-12 13:15:48.755888
# 173
# 2021-04-12 13:15:50.294505
# 174
# 2021-04-12 13:15:51.235275
# 175
# 2021-04-12 13:15:59.477864
# 176
# 2021-04-12 13:16:04.926666
# 177
# 2021-04-12 13:16:08.548310
# 178
# 2021-04-12 13:16:12.890169
# 179
# 2021-04-12 13:16:24.221135
# 180
# 2021-04-12 13:16:34.941095
# 181
# 2021-04-12 13:16:48.807504
# 182
# 2021-04-12 13:17:06.342261
# 183
# 2021-04-12 13:17:10.960112
# 184
# 2021-04-12 13:17:11.281443
# 185
# 2021-04-12 13:17:11.610130
# 186
# 2021-04-12 13:17:11.853437
# 187
# 2021-04-12 13:17:12.138797
# 188
# 2021-04-12 13:17:12.719812
# 189
# 2021-04-12 13:17:24.289400
# 190
# 2021-04-12 13:17:45.252099
# 191
# 2021-04-12 13:17:56.617247
# 192
# 2021-04-12 13:18:04.445692
# 193
# 2021-04-12 13:18:12.450627
# 194
# 2021-04-12 13:18:21.597451
# 195
# 2021-04-12 13:18:32.115903
# 196
# 2021-04-12 13:18:40.357106
# 197
# 2021-04-12 13:18:42.059863

# %% [markdown]
# Create a pandas dataframe for the MAG and CORE entries, each with aolumn for id, title and authors

# %%
import pandas as pd

mag_auth = pd.DataFrame(mag_auth, columns =['Mag_id', 'Mag_Authors','Mag_Title'])

# %%
core_auth = pd.DataFrame(core_auth, columns =['Core_id', 'Core_Authors','Core_Title'])

# %% [markdown]
# Merge both dataframes based on the list of entry matches. Each match is now a line in the dataframe, containing both author-lists and titles from the MAG and the CORE entry

# %%
auth_df = pd.DataFrame(mlist,columns =['Mag_id','Core_id'])
auth_df = auth_df.merge(mag_auth,on=['Mag_id']).merge(core_auth,on=['Core_id'])

# %%
auth_df
# Out:
#              Mag_id   Core_id  \
# 0        1000000185  42023535
# 1         100000407  82235102
# 2        1000007777   9554974
# 3        1000013286  36706632
# 4        1000014399   6112882
# ...             ...       ...
# 3567226   999972508  82484073
# 3567227    99997835  82317676
# 3567228   999981119  18590244
# 3567229   999981997  31012454
# 3567230    99998370  25279111
#
#                                                Mag_Authors  \
# 0            [{'name': 'Sanpei Usui', 'id': '2398577680'}]
# 1        [{'name': 'Surender Deora', 'id': '2132854008'...
# 2        [{'name': 'Shengye Zeng', 'id': '2163875822'},...
# 3        [{'name': 'Clifford Allison. Rose', 'id': '251...
# 4        [{'name': 'Nicky Stanley', 'id': '2171225193'}...
# ...                                                    ...
# 3567226  [{'name': 'Rebecca A. Fischer', 'id': '2164566...
# 3567227  [{'name': 'Alice K. Jacobs', 'id': '2807342118'}]
# 3567228          [{'name': 'Zhe Kan', 'id': '2649816162'}]
# 3567229  [{'name': 'Georg Futter', 'id': '2124207548'},...
# 3567230  [{'name': 'A P De Haas', 'id': '2791063430'}, ...
#
#                                                  Mag_Title  \
# 0        Complex structures on partial compactification...
# 1        Cardiac Epithelioid Leiomyosarcoma as Both Int...
# 2        The investigation of material removal in bonne...
# 3        Time multiplexing of compensation in control s...
# 4        Disclosing Disability: Disabled students and p...
# ...                                                    ...
# 3567226  High pressure metal–silicate partitioning of N...
# 3567227  Women, ischemic heart disease, revascularizati...
# 3567228  Electrical properties of carbon structures : c...
# 3567229  Modeling of transport and degradation processe...
# 3567230  Very low mass microcables for the ALICE silico...
#
#                                               Core_Authors  \
# 0                                           [Usui, Sanpei]
# 1        [Deora, Surender, Gurmukhani, Sunil, Shah, San...
# 2               [Zeng, Shengye, Blunt, Liam, Jiang, Xiang]
# 3                                [Rose, Clifford Allison.]
# 4        [Stanley, Nicky, Ridley, Julie, Harris, Jessic...
# ...                                                    ...
# 3567226  [Fischer, Rebecca A., Nakajima, Yoichi, Campbe...
# 3567227                                 [Jacobs, Alice K.]
# 3567228                                         [Kan, Zhe]
# 3567229      [Futter, Georg, Jahnke, Thomas, Latz, Arnulf]
# 3567230  [De Haas, A P, Oskamp, C J, Van den Brink, A, ...
#
#                                                 Core_Title
# 0        Complex structures on partial compactification...
# 1        Cardiac Epithelioid Leiomyosarcoma as Both Int...
# 2        The investigation of material removal in bonne...
# 3        Time multiplexing of compensation in control s...
# 4        Disclosing Disability: Disabled students and p...
# ...                                                    ...
# 3567226  High pressure metal–silicate partitioning of N...
# 3567227  Women, Ischemic Heart Disease, Revascularizati...
# 3567228  Electrical properties of carbon structures : c...
# 3567229  Modeling of transport and degradation processe...
# 3567230  Very low mass microcables for the ALICE silico...
#
# [3567231 rows x 6 columns]

# %% [markdown]
# Create columns containing the length of the authorlists. Differing list lengths may be an indicator for incorrect matches.
# Store data for accessing later, without having to create the dataframes from scratch again.

# %%
auth_df['Len_mag'] = [len(auth) for auth in auth_df['Mag_Authors']]
auth_df['Len_core'] = [len(auth) for auth in auth_df['Core_Authors']]

# %%
auth_df.to_json('results/mag_match/matching_checkup.json')

# %%
auth_df = pd.read_json('results/mag_match/matching_checkup.json')

# %% [markdown]
# Define function to compare authorlists. Function takes two lists a and b, and returns a tuple with four values:
#
#     The number of authors of both lists that match by either first or last name
#     The number of authors that match by their first name
#     The number of authors that match by their last name
#     The number of authors of both lists that match by both their first and last name
#
# Method is tested on an example list to see whether it returns the intended values

# %%
def compare_l_f(a,b):
    m_l_f = 0
    m_l = 0
    m_f = 0
    m_l_f_both = 0
    for auth_m in a:
        lname = auth_m['name'].split()[-1].lower()
        fname = auth_m['name'].split()[0].lower()
        for n in b:
            if not isinstance(n,str):
                continue
            nl = n.lower()
            lhit = False
            fhit = False
            if nl.find(lname)>-1:
                m_l += 1
                lhit = True
            if nl.find(fname)>-1:
                m_f += 1
                fhit = True
            if lhit and fhit:
                m_l_f_both += 1
            if lhit or fhit:
                m_l_f += 1
            
    return (m_l_f, m_l, m_f, m_l_f_both)

# %%
compare_l_f([{'name': 'Anna Maria', 'id': '2398577680'},{'name': 'Julia Bauer', 'id': '2398577680'},{'name': 'Petra Müller', 'id': '2398577680'},{'name': 'Vivian Schneider', 'id': '2398577680'}],['Maria, Anna','Bauer, Greta','Tante, Petra','Usui, Sanpei'])
# Out:
# (3, 2, 2, 1)

# %% [markdown]
# Import module for Levenshtein string comparison
# Define compare_lev as function which performs Levenshtein compare between the last name of the MAG-author and all authors in the CORE list. Returns the number of MAG authors for whom a sufficiently similar name was found in the CORE list.

# %%
from Levenshtein import distance as levenshtein_distance
def levenshtein_compare(t1, t2):
    if not t1 or not t2:
        return False
    return (levenshtein_distance(t1.lower(), t2.lower()) < abs(len(t1)-len(t2)) + 0.1*min(len(t1),len(t2)) and not ((len(t1) < 20 or len(t2) < 20) and abs(len(t1)-len(t2)) > 30))

# %%
def compare_lev(mag,core):
    return sum([any([True if isinstance(core_a,str) and levenshtein_compare(core_a, mag_a['name'].split()[-1]) else False for core_a in core]) for mag_a in mag])

# %% [markdown]
# Use the function defined above to find the numbers of authors matched by first, last, both or either of those names and store the numbers in a column each

# %%
auth_df['Known_comb'] = [compare_l_f(mag,core) for mag, core in zip(auth_df['Mag_Authors'],auth_df['Core_Authors'])]

# %%
auth_df['Known_l'] = [x[1] for x in auth_df['Known_comb']]
auth_df['Known_f'] = [x[2] for x in auth_df['Known_comb']]
auth_df['Known_l_f'] = [x[0] for x in auth_df['Known_comb']]
auth_df['Known_l+f'] = [x[3] for x in auth_df['Known_comb']]

# %%
auth_df
# Out:
#              Mag_id   Core_id  \
# 0        1000000185  42023535
# 1         100000407  82235102
# 2        1000007777   9554974
# 3        1000013286  36706632
# 4        1000014399   6112882
# ...             ...       ...
# 3567226   999972508  82484073
# 3567227    99997835  82317676
# 3567228   999981119  18590244
# 3567229   999981997  31012454
# 3567230    99998370  25279111
#
#                                                Mag_Authors  \
# 0            [{'name': 'Sanpei Usui', 'id': '2398577680'}]
# 1        [{'name': 'Surender Deora', 'id': '2132854008'...
# 2        [{'name': 'Shengye Zeng', 'id': '2163875822'},...
# 3        [{'name': 'Clifford Allison. Rose', 'id': '251...
# 4        [{'name': 'Nicky Stanley', 'id': '2171225193'}...
# ...                                                    ...
# 3567226  [{'name': 'Rebecca A. Fischer', 'id': '2164566...
# 3567227  [{'name': 'Alice K. Jacobs', 'id': '2807342118'}]
# 3567228          [{'name': 'Zhe Kan', 'id': '2649816162'}]
# 3567229  [{'name': 'Georg Futter', 'id': '2124207548'},...
# 3567230  [{'name': 'A P De Haas', 'id': '2791063430'}, ...
#
#                                                  Mag_Title  \
# 0        Complex structures on partial compactification...
# 1        Cardiac Epithelioid Leiomyosarcoma as Both Int...
# 2        The investigation of material removal in bonne...
# 3        Time multiplexing of compensation in control s...
# 4        Disclosing Disability: Disabled students and p...
# ...                                                    ...
# 3567226  High pressure metal–silicate partitioning of N...
# 3567227  Women, ischemic heart disease, revascularizati...
# 3567228  Electrical properties of carbon structures : c...
# 3567229  Modeling of transport and degradation processe...
# 3567230  Very low mass microcables for the ALICE silico...
#
#                                               Core_Authors  \
# 0                                           [Usui, Sanpei]
# 1        [Deora, Surender, Gurmukhani, Sunil, Shah, San...
# 2               [Zeng, Shengye, Blunt, Liam, Jiang, Xiang]
# 3                                [Rose, Clifford Allison.]
# 4        [Stanley, Nicky, Ridley, Julie, Harris, Jessic...
# ...                                                    ...
# 3567226  [Fischer, Rebecca A., Nakajima, Yoichi, Campbe...
# 3567227                                 [Jacobs, Alice K.]
# 3567228                                         [Kan, Zhe]
# 3567229      [Futter, Georg, Jahnke, Thomas, Latz, Arnulf]
# 3567230  [De Haas, A P, Oskamp, C J, Van den Brink, A, ...
#
#                                                 Core_Title  Len_mag  Len_core  \
# 0        Complex structures on partial compactification...        1         1
# 1        Cardiac Epithelioid Leiomyosarcoma as Both Int...        6         6
# 2        The investigation of material removal in bonne...        3         3
# 3        Time multiplexing of compensation in control s...        1         1
# 4        Disclosing Disability: Disabled students and p...        5         5
# ...                                                    ...      ...       ...
# 3567226  High pressure metal–silicate partitioning of N...        9         9
# 3567227  Women, Ischemic Heart Disease, Revascularizati...        1         1
# 3567228  Electrical properties of carbon structures : c...        1         1
# 3567229  Modeling of transport and degradation processe...        3         3
# 3567230  Very low mass microcables for the ALICE silico...        7         7
#
#          Known_l  Known_f  Known_l_f  Known_l+f
# 0              1        1          1          1
# 1              8        6          8          6
# 2              3        3          3          3
# 3              1        1          1          1
# 4              5        5          5          5
# ...          ...      ...        ...        ...
# 3567226        9        9          9          9
# 3567227        1        1          1          1
# 3567228        1        1          1          1
# 3567229        3        3          3          3
# 3567230        7       12         15          4
#
# [3567231 rows x 12 columns]

# %%
auth_df = auth_df.drop(['Known_comb'],axis=1)

# %% [markdown]
# Now we look for potential mismatches. We start by taking a look at the number of antries where CORE contains more authors than MAG

# %%
auth_df[auth_df.Len_mag < auth_df.Len_core]
# Out:
#              Mag_id    Core_id  \
# 8         100002650  143745708
# 23        100008419   11795336
# 43        100018775  143746796
# 48       2247017209   36020396
# 71       1000276684  143798957
# ...             ...        ...
# 3567109    99960701  143747665
# 3567139    99969003  143751704
# 3567159    99975286   33012342
# 3567204   999908821     191028
# 3567216    99993868  143735357
#
#                                                Mag_Authors  \
# 8        [{'name': 'Linda Jean. Koska', 'id': '66207075...
# 23         [{'name': 'Nizam Dahalan', 'id': '2337882912'}]
# 43            [{'name': 'Tein-Yow Yu', 'id': '849224505'}]
# 48           [{'name': 'T. Aaltonen', 'id': '2551340074'}]
# 71       [{'name': 'Janet Lynn Wagner', 'id': '26571556...
# ...                                                    ...
# 3567109  [{'name': 'Stephen Marcus Green', 'id': '20987...
# 3567139  [{'name': 'Deborah Ann Coughlin', 'id': '21239...
# 3567159  [{'name': 'N N Pillai', 'id': '2636378198'}, {...
# 3567204  [{'name': 'Eilean Hooper-Greenhill', 'id': '22...
# 3567216  [{'name': 'Noelle C Jacobson', 'id': '27138659...
#
#                                                  Mag_Title  \
# 8        THE STRUCTURE AND HARMONIC LANGUAGE OF "THE DO...
# 23       Development of a computer program for rocket a...
# 43       Efficient backtracking strategies in test gene...
# 48       Measurement of the p anti-p to t anti-t Produc...
# 71       Characterization of the detergent sodium chola...
# ...                                                    ...
# 3567109  Manipulation of a rectangular air jet using pi...
# 3567139  Fitting the school to the child: A case histor...
# 3567159  Brackishwater prawn farming in the Ashtamudi l...
# 3567204  Developing a scheme for finding evidence of th...
# 3567216  The Role Of The Small GTPASE RAB14 In Apical P...
#
#                                               Core_Authors  \
# 8                 [Koska, Linda Jean., Koska, Linda Jean.]
# 23       [Dahalan, Md. Nizam, Su, Vin Cent, Ammoo, Mohd...
# 43              [Yu, Tein-Yow, 1961-, Yu, Tein-Yow, 1961-]
# 48       [Aaltonen, T., Casal, Bruno, Cuevas, Javier, G...
# 71                [Wagner, Janet Lynn, Wagner, Janet Lynn]
# ...                                                    ...
# 3567109  [Green, Stephen Marcus, 1957-, Green, Stephen ...
# 3567139  [Coughlin, Deborah Ann, 1953-, Coughlin, Debor...
# 3567159  [Nair, P V Ramachandran, Pillai, N N, Pillai, ...
# 3567204               [Hooper-Greenhill, Eilean, Resource]
# 3567216           [Jacobson, Noelle C, Jacobson, Noelle C]
#
#                                                 Core_Title  Len_mag  Len_core  \
# 8        THE STRUCTURE AND HARMONIC LANGUAGE OF "THE DO...        1         2
# 23       Development of a computer program for rocket a...        1         3
# 43       Efficient backtracking strategies in test gene...        1         2
# 48       Measurement of the pp̅ →tt̅ production cross s...        1        13
# 71       Characterization of the detergent sodium chola...        1         2
# ...                                                    ...      ...       ...
# 3567109  Manipulation of a rectangular air jet using pi...        1         2
# 3567139  Fitting the school to the child: A case histor...        1         2
# 3567159  Brackishwater prawn farming in the Ashtamudi l...        7         8
# 3567204  Developing a scheme for finding evidence of th...        1         2
# 3567216  The Role Of The Small GTPASE RAB14 In Apical P...        1         2
#
#          Known_l  Known_f  Known_l_f  Known_l+f
# 8              2        2          2          2
# 23             1        1          1          1
# 43             2        2          2          2
# 48             1        1          1          1
# 71             2        2          2          2
# ...          ...      ...        ...        ...
# 3567109        2        2          2          2
# 3567139        2        2          2          2
# 3567159       13       28         32          9
# 3567204        1        1          1          1
# 3567216        2        2          2          2
#
# [99816 rows x 12 columns]

# %%
auth_df[auth_df.Len_mag < auth_df.Len_core].sample(20)

# %% [markdown]
# Results are stored again as the list compares take some time to complete

# %%
auth_df.to_json('results/mag_match/matching_checkup.json')

# %% [markdown]
# We take a look at some entries with differing length in detail

# %%
auth_df.loc[3567139].Mag_Authors
# Out:
# [{'name': 'Deborah Ann Coughlin', 'id': '2123992730'}]

# %%
auth_df.loc[3567139].Core_Authors
# Out:
# ['Coughlin, Deborah Ann, 1953-', 'Coughlin, Deborah Ann, 1953-']

# %%
auth_df.loc[3567159].Mag_Authors
# Out:
# [{'name': 'N N Pillai', 'id': '2636378198'},
#  {'name': 'V K Pillai', 'id': '2699148515'},
#  {'name': 'P P Pillai', 'id': '2645088690'},
#  {'name': 'K J Mathew', 'id': '2656141606'},
#  {'name': 'C P Gopinathan', 'id': '2797365781'},
#  {'name': 'V K Balachandran', 'id': '2636299615'},
#  {'name': 'D Vincent', 'id': '2674116733'}]

# %%
auth_df.loc[3567159].Core_Authors
# Out:
# ['Nair, P V Ramachandran',
#  'Pillai, N N',
#  'Pillai, V K',
#  'Pillai, P P',
#  'Mathew, K J',
#  'Gopinathan, C P',
#  'Balachandran, V K',
#  'Vincent, D']

# %%
auth_df.loc[296].Mag_Authors
# Out:
# [{'name': 'Asier Jayo', 'id': '1756440050'},
#  {'name': 'Dina Pabón', 'id': '2168065855'},
#  {'name': 'Pedro Lastres', 'id': '2196020418'},
#  {'name': 'V. Jimenez-Yuste', 'id': '2109685147'},
#  {'name': 'Consuelo González-Manchón', 'id': '1974979943'}]

# %%
auth_df.loc[296].Core_Authors
# Out:
# ['Jayo, Asier',
#  'Pabón, Dina',
#  'Lastres, Pedro',
#  'Jiménez-Yuste, Victor',
#  'González-Manchón, Consuelo']

# %% [markdown]
# We take a look at the entries where not all authors could be matched and take some samples.

# %%
auth_df[(auth_df.Known_l_f < auth_df.Len_mag) & (auth_df.Known_l_f < auth_df.Len_core)]
# Out:
#              Mag_id   Core_id  \
# 116      2005087574  19588467
# 296      1001191458  36108925
# 521       100208094     70286
# 657      1002592871  42931908
# 879      1003415266  94283594
# ...             ...       ...
# 3566745   998132775  10924117
# 3566787   998279759  11857567
# 3567096   999549861  82522043
# 3567148   999726932  36088314
# 3567196   999892512  81171909
#
#                                                Mag_Authors  \
# 116      [{'name': 'A. Benavent-Climent', 'id': '173474...
# 296      [{'name': 'Asier Jayo', 'id': '1756440050'}, {...
# 521      [{'name': 'Olga Mudraya', 'id': '2076331398'},...
# 657      [{'name': 'Gyula Katona', 'id': '2794350191'},...
# 879      [{'name': 'Zhuravlev Yuriy Ivanovich', 'id': '...
# ...                                                    ...
# 3566745  [{'name': 'Bohumír Cagaš', 'id': '1703597667'}...
# 3566787  [{'name': 'G. Modla', 'id': '1527749307'}, {'n...
# 3567096  [{'name': 'Andrea Sujová', 'id': '2310056901'}...
# 3567148  [{'name': 'Irene Gonzalez-Valls', 'id': '20322...
# 3567196  [{'name': 'Pranas Baltrenas', 'id': '226744247...
#
#                                                  Mag_Title  \
# 116      Shaking table tests of structures with hystere...
# 296      Type II Glanzmann thrombasthenia in a compound...
# 521      English-Russian-Finnish cross-language compari...
# 657                    Length of Sums in a Minkowski Space
# 879         The new approaches to problem of polymorbidity
# ...                                                    ...
# 3566745  The effect of grasses grown for seed in mixtur...
# 3566787  Entrainer selection for pressure swing batch d...
# 3567096  Modern Methods of Process Management Used in S...
# 3567148  Aligned semiconductor oxide nanostructures for...
# 3567196  Experimental Research of Odours Arising During...
#
#                                               Core_Authors  \
# 116      [Benavent Climent, Amadeo, Escolano Margarit, ...
# 296      [Jayo, Asier, Pabón, Dina, Lastres, Pedro, Jim...
# 521      [Mudraya, O., Piao, S., Lofberg, L., Rayson, P...
# 657          [Katona, Gyula, Mayer, R., Woyczynski, W. A.]
# 879                  [Zhuravlev, Y. I., Tkhorikova, V. N.]
# ...                                                    ...
# 3566745                    [Cagas, Bohumir, Machac, Radek]
# 3566787         [Modla, Gábor, Láng, Péter, Kopasz, Árpád]
# 3567096            [Sujova, Andrea, Marcinekova, Katarina]
# 3567148  [González-Valls, Irene, González-García, Lola,...
# 3567196  [Baltrenas, Pranas, Misevicius, Antonas, Macai...
#
#                                                 Core_Title  Len_mag  Len_core  \
# 116      Shaking table tests of structures with hystere...        2         2
# 296      Type II Glanzmann thrombasthenia in a compound...        5         5
# 521      English-Russian-Finnish cross-language compari...        5         5
# 657                    Length of Sums in a Minkowski Space        3         3
# 879         The new approaches to problem of polymorbidity        2         2
# ...                                                    ...      ...       ...
# 3566745  The effect of grasses grown for seed in mixtur...        2         2
# 3566787  Entrainer selection for pressure swing batch d...        3         3
# 3567096  Modern Methods of Process Management Used in S...        2         2
# 3567148  Aligned semiconductor oxide nanostructures for...        8         8
# 3567196  Experimental Research of Odours Arising During...        4         4
#
#          Known_l  Known_f  Known_l_f  Known_l+f
# 116            0        1          1          0
# 296            4        4          4          4
# 521            4        0          4          0
# 657            2        2          2          2
# 879            0        1          1          0
# ...          ...      ...        ...        ...
# 3566745        0        1          1          0
# 3566787        2        0          2          0
# 3567096        0        1          1          0
# 3567148        6        6          7          5
# 3567196        2        3          3          2
#
# [50114 rows x 12 columns]

# %%
auth_df[(auth_df.Known_f < auth_df.Len_mag) & (auth_df.Known_f < auth_df.Len_core)]
# Out:
#              Mag_id    Core_id  \
# 10       1000030475   43097361
# 13          1000056   37502359
# 17       1000064551   81137944
# 20       1000069329   55537363
# 40        100017267   29258100
# ...             ...        ...
# 3567195   999883381   36047224
# 3567196   999892512   81171909
# 3567197    99989776      78248
# 3567210   999922911   48165576
# 3567218    99994464  143770646
#
#                                                Mag_Authors  \
# 10       [{'name': 'Clara Kulich', 'id': '1971919205'},...
# 13       [{'name': 'Fabricia Petronilho', 'id': '205885...
# 17       [{'name': 'Daniel Menezes Silvestre', 'id': '2...
# 20       [{'name': 'Halszka Jarodzka', 'id': '302381991...
# 40         [{'name': 'David Lentink', 'id': '2116162051'}]
# ...                                                    ...
# 3567195  [{'name': 'Pelayo González', 'id': '2175088314...
# 3567196  [{'name': 'Pranas Baltrenas', 'id': '226744247...
# 3567197   [{'name': 'Nicholas Ryder', 'id': '2097380707'}]
# 3567210  [{'name': 'Julien Dagher', 'id': '2078178394'}...
# 3567218  [{'name': 'Tika R. Verma', 'id': '2797792933'}...
#
#                                                  Mag_Title  \
# 10       Signaling change during a crisis: refining con...
# 13       Gastrin-Releasing Peptide Receptor Antagonism ...
# 17       Feasibility study of calibration strategy for ...
# 20                            Cognitive Skills in Medicine
# 40       Exploring the biofluiddynamics of swimming and...
# ...                                                    ...
# 3567195  Functional polymorphism in the promoter region...
# 3567196  Experimental Research of Odours Arising During...
# 3567197  The finacial services authority and money laun...
# 3567210  Wild-type VHL Clear Cell Renal Cell Carcinomas...
# 3567218  Rehabilitation of Copper Mine Tailing Slopes U...
#
#                                               Core_Authors  \
# 10       [Kulich, C, Lorenzi-Cioldi, F, Iacoviello, V, ...
# 13       [Petronilho, Fabricia, Vuolo, Francieli, Galan...
# 17       [Silvestre, Daniel Menezes, Barbosa, Felipe Mi...
# 20       [Jarodzka, Halszka, Boshuizen, Els, Kirschner,...
# 40                                           [Lentink, D.]
# ...                                                    ...
# 3567195  [González, P., Díez-Juan, Antonio, Andrés, Vic...
# 3567196  [Baltrenas, Pranas, Misevicius, Antonas, Macai...
# 3567197                                        [Ryder, N.]
# 3567210  [Dagher, Julien, Kammerer-Jacquet, Solene-Flor...
# 3567218   [Verma, Tika R., Ludeke, Kenneth L., Day, A. D.]
#
#                                                 Core_Title  Len_mag  Len_core  \
# 10       Signaling change during a crisis: Refining con...        5         5
# 13       Gastrin-Releasing Peptide Receptor Antagonism ...       23        22
# 17       Feasibility study of calibration strategy for ...        5         5
# 20       Cognitive Skills in Catheter-based Cardiovascu...        3         3
# 40       Exploring the biofluiddynamics of swimming and...        1         1
# ...                                                    ...      ...       ...
# 3567195  Functional polymorphism in the promoter region...        5         5
# 3567196  Experimental Research of Odours Arising During...        4         4
# 3567197  The finacial services authority and money laun...        1         1
# 3567210  Wild-type VHL Clear Cell Renal Cell Carcinomas...       14        14
# 3567218  Rehabilitation of Copper Mine Tailing Slopes U...        3         3
#
#          Known_l  Known_f  Known_l_f  Known_l+f
# 10             5        0          5          0
# 13            23       21         25         19
# 17             5        4          5          4
# 20             3        2          3          2
# 40             1        0          1          0
# ...          ...      ...        ...        ...
# 3567195        4        4          5          3
# 3567196        2        3          3          2
# 3567197        1        0          1          0
# 3567210       14       12         15         11
# 3567218        3        2          3          2
#
# [668529 rows x 12 columns]

# %%
auth_df[(auth_df.Known_l < auth_df.Len_mag) & (auth_df.Known_l < auth_df.Len_core)]
# Out:
#              Mag_id    Core_id  \
# 116      2005087574   19588467
# 199       100079032   12356592
# 235      1000955919  130019579
# 255       100103939   16388691
# 296      1001191458   36108925
# ...             ...        ...
# 3567016   999271521   33667039
# 3567096   999549861   82522043
# 3567148   999726932   36088314
# 3567195   999883381   36047224
# 3567196   999892512   81171909
#
#                                                Mag_Authors  \
# 116      [{'name': 'A. Benavent-Climent', 'id': '173474...
# 199      [{'name': 'O. O. Ajayi', 'id': '2470271829'}, ...
# 235         [{'name': 'Anik Faujiah', 'id': '1995878208'}]
# 255      [{'name': 'Ryota Nakajima', 'id': '2099235777'...
# 296      [{'name': 'Asier Jayo', 'id': '1756440050'}, {...
# ...                                                    ...
# 3567016  [{'name': 'Saskia Brix', 'id': '2048068937'}, ...
# 3567096  [{'name': 'Andrea Sujová', 'id': '2310056901'}...
# 3567148  [{'name': 'Irene Gonzalez-Valls', 'id': '20322...
# 3567195  [{'name': 'Pelayo González', 'id': '2175088314...
# 3567196  [{'name': 'Pranas Baltrenas', 'id': '226744247...
#
#                                                  Mag_Title  \
# 116      Shaking table tests of structures with hystere...
# 199      Assessment of Wind Power Potential and Wind El...
# 235      Aspek hukum pewarnaan rambut: studi kasus di k...
# 255      Sedimentation impacts on the growth rates of t...
# 296      Type II Glanzmann thrombasthenia in a compound...
# ...                                                    ...
# 3567016  IceAGE - Icelandic marine Animals: Genetics an...
# 3567096  Modern Methods of Process Management Used in S...
# 3567148  Aligned semiconductor oxide nanostructures for...
# 3567195  Functional polymorphism in the promoter region...
# 3567196  Experimental Research of Odours Arising During...
#
#                                               Core_Authors  \
# 116      [Benavent Climent, Amadeo, Escolano Margarit, ...
# 199           [Ajayi, O. O., Fagbenle, R. O., Katende, J.]
# 235                                       [Faujiyah, Anik]
# 255      [R., Nakajima, T., Yoshida, Y., Fuchinove, T.,...
# 296      [Jayo, Asier, Pabón, Dina, Lastres, Pedro, Jim...
# ...                                                    ...
# 3567016  [Brix, Saskia, Martinez, Pedro, Svavarsson, Jö...
# 3567096            [Sujova, Andrea, Marcinekova, Katarina]
# 3567148  [González-Valls, Irene, González-García, Lola,...
# 3567195  [González, P., Díez-Juan, Antonio, Andrés, Vic...
# 3567196  [Baltrenas, Pranas, Misevicius, Antonas, Macai...
#
#                                                 Core_Title  Len_mag  Len_core  \
# 116      Shaking table tests of structures with hystere...        2         2
# 199      Assessment of Wind Power Potential and Wind El...        3         3
# 235      Aspek hukum pewarnaan rambut: studi kasus di k...        1         1
# 255      Sedimentation impacts on the growth rates of t...        8         8
# 296      Type II Glanzmann thrombasthenia in a compound...        5         5
# ...                                                    ...      ...       ...
# 3567016  IceAGE - Icelandic marine Animals: Genetics an...       11        11
# 3567096  Modern Methods of Process Management Used in S...        2         2
# 3567148  Aligned semiconductor oxide nanostructures for...        8         8
# 3567195  Functional polymorphism in the promoter region...        5         5
# 3567196  Experimental Research of Odours Arising During...        4         4
#
#          Known_l  Known_f  Known_l_f  Known_l+f
# 116            0        1          1          0
# 199            2        3          3          2
# 235            0        1          1          0
# 255            7        9         13          3
# 296            4        4          4          4
# ...          ...      ...        ...        ...
# 3567016       10       11         11         10
# 3567096        0        1          1          0
# 3567148        6        6          7          5
# 3567195        4        4          5          3
# 3567196        2        3          3          2
#
# [168052 rows x 12 columns]

# %%
s_m_ids = set(load(open('results/mag_match/ids_for_single_multi_core_extraction.json','r'))['ids'])
auth_df[(auth_df.Core_id.isin(s_m_ids)) & (auth_df.Known_l_f < auth_df.Len_mag) & (auth_df.Known_l_f < auth_df.Len_core)]
# Out:
#              Mag_id   Core_id  \
# 521       100208094     70286
# 962       100373180  44234818
# 1239     1004814664  82378655
# 3148     1930314859  39279954
# 3526     1013294644  82002019
# ...             ...       ...
# 3564943   991187291  48295270
# 3565686    99412176  11758582
# 3565835   994716540  70382584
# 3565900   994976729  36015984
# 3567096   999549861  82522043
#
#                                                Mag_Authors  \
# 521      [{'name': 'Olga Mudraya', 'id': '2076331398'},...
# 962      [{'name': 'E. Adli', 'id': '2050692267'}, {'na...
# 1239      [{'name': 'Hulya Caliskan', 'id': '2133431902'}]
# 3148     [{'name': 'ShikamaT.', 'id': '2249092368'}, {'...
# 3526     [{'name': 'Adrian Munguia-Vega', 'id': '545238...
# ...                                                    ...
# 3564943  [{'name': 'Vincenzo De Maio', 'id': '215774425...
# 3565686  [{'name': 'S. N. Losa', 'id': '2613851832'}, {...
# 3565835  [{'name': 'Yael R. Nobel', 'id': '1977778394'}...
# 3565900  [{'name': 'Jesús Ruiz Amaya', 'id': '276399584...
# 3567096  [{'name': 'Andrea Sujová', 'id': '2310056901'}...
#
#                                                  Mag_Title  \
# 521      English-Russian-Finnish cross-language compari...
# 962      Status of an automatic Beam Steering for the C...
# 1239              Technological Change and Economic Growth
# 3148     Plasma polarization spectroscopy of atomic and...
# 3526     Marine reserves help preserve genetic diversit...
# ...                                                    ...
# 3564943  Modelling energy consumption of network transf...
# 3565686  Estimating biological parameters of a size-dep...
# 3565835  Metabolic and metagenomic outcomes from early-...
# 3565900  A 0.13μm CMOS Current Steering D/A Converter f...
# 3567096  Modern Methods of Process Management Used in S...
#
#                                               Core_Authors  \
# 521      [Mudraya, O., Piao, S., Lofberg, L., Rayson, P...
# 962      [Adli, E, Corsini, R, Dabrowski, A, Schulte, D...
# 1239                              [Çalışkan, Hülya Kesici]
# 3148     [Shikama, T., Fujii, K., Kado, S., Zushi, H., ...
# 3526     [Munguía-Vega, Adrián, Sáenz-Arroyo, Andrea, G...
# ...                                                    ...
# 3564943  [De Maio, Vincenzo, Prodan, Radu, Benedict, Sh...
# 3565686  [Loza, Svetlana, Schröter, Jens, Wenzel, Manfr...
# 3565835  [Abubucker, Sahar, Zhou, Yanjiao, Mitreva, Mak...
# 3565900  [Ruiz Amaya, Jesús, Fernández-Bootello, Juan F...
# 3567096            [Sujova, Andrea, Marcinekova, Katarina]
#
#                                                 Core_Title  Len_mag  Len_core  \
# 521      English-Russian-Finnish cross-language compari...        5         5
# 962      Status of an automatic Beam Steering for the C...        8         8
# 1239             Technological Change and Economic Growth         1         1
# 3148     Plasma polarization spectroscopy of atomic and...        9         9
# 3526     Marine reserves help preserve genetic diversit...        7         7
# ...                                                    ...      ...       ...
# 3564943  Modelling Energy Consumption of Network Transf...        4         4
# 3565686  Estimating biological parameters of a size-dep...        4         5
# 3565835  Metabolic and metagenomic outcomes from early-...       20         6
# 3565900  A 0.13μm CMOS Current Steering D/A Converter f...        4         4
# 3567096  Modern Methods of Process Management Used in S...        2         2
#
#          Known_l  Known_f  Known_l_f  Known_l+f
# 521            4        0          4          0
# 962            6        1          6          1
# 1239           0        0          0          0
# 3148           0        0          0          0
# 3526           6        6          6          6
# ...          ...      ...        ...        ...
# 3564943        3        3          3          3
# 3565686        3        0          3          0
# 3565835        5        5          5          5
# 3565900        3        3          3          3
# 3567096        0        1          1          0
#
# [22667 rows x 12 columns]

# %%
auth_df[auth_df.Known_l_f == 0].sample(n=20)
# Out:
#              Mag_id   Core_id  \
# 2223095  2140293347  81061579
# 2905384  2472323562  81806797
# 3036791  2549714162  81271064
# 618489   1966610449  81819726
# 1190458  2025099632  81195933
# 2077065  2121494685  81701871
# 3121647  2589066055  81276086
# 2283718  2148113627  81804806
# 1180063  2024027755  81745018
# 2803267  2341141931  81792727
# 2388555  2161634984  81083386
# 2635758  2268422068  81823724
# 876485   1992985920  81705433
# 3536979   863440679  81877882
# 1396220  2046203927  81159409
# 3126937  2591060705  81741499
# 2923761  2487378026  81165379
# 1516491  2058573160  81537625
# 868312   1992138428  81855964
# 941425   1999600272  81053633
#
#                                                Mag_Authors  \
# 2223095  [{'name': 'Michael P. W. Grocott', 'id': '1171...
# 2905384  [{'name': 'Dona Fleishaker', 'id': '2316449986...
# 3036791  [{'name': 'Jiang Long', 'id': '2594970808'}, {...
# 618489   [{'name': 'Ye Ding', 'id': '2766019190'}, {'na...
# 1190458  [{'name': 'Berno Bucker', 'id': '2037640033'},...
# 2077065  [{'name': 'Philipp M. Keune', 'id': '243249279...
# 3121647  [{'name': 'Jeffrey J. Kim', 'id': '2543414348'...
# 2283718  [{'name': 'N. Giordano', 'id': '2151326331'}, ...
# 1180063  [{'name': 'Chien-Chung Kuo', 'id': '2420987193...
# 2803267  [{'name': 'Vibeke Børsholt Rudkjøbing', 'id': ...
# 2388555  [{'name': 'Maria Luiza da Matta Felisberto Fer...
# 2635758  [{'name': 'Izabela Jośko', 'id': '108227584'},...
# 876485   [{'name': 'A.K. Immers', 'id': '2063284721'}, ...
# 3536979  [{'name': 'Jaakko Yrjänä', 'id': '2886677324'}...
# 1396220  [{'name': 'Teresa To', 'id': '2098421486'}, {'...
# 3126937  [{'name': 'Jim Stirrup', 'id': '2499884419'}, ...
# 2923761  [{'name': 'Shuai-Qi Yang', 'id': '2499478997'}...
# 1516491  [{'name': 'Lauren L. Bischel', 'id': '20523076...
# 868312   [{'name': 'Xin Li', 'id': '2670882350'}, {'nam...
# 941425   [{'name': 'Banu Eyüboglu', 'id': '2531842476'}...
#
#                                                  Mag_Title Core_Authors  \
# 2223095                    Everest 60 years on: what next?           []
# 2905384  Safety and pharmacodynamic dose response of sh...           []
# 3036791  Prevalence and correlates of problematic smart...           []
# 618489   Fish genome manipulation and directional breeding           []
# 1190458  The effect of reward on orienting and reorient...           []
# 2077065  Dynamic walking features and improved walking ...           []
# 3121647  Universal electronic-cigarette test: physioche...           []
# 2283718                     Physical modeling of the piano           []
# 1180063        Ankle morphometry in the Chinese population           []
# 2803267  Comparing culture and molecular methods for th...           []
# 2388555  Caries prevalence and impact on oral health-re...           []
# 2635758  The bioavailability and toxicity of ZnO and Ni...           []
# 876485   Iron addition as a shallow lake restoration me...           []
# 3536979  Early introduction of solid foods and the low ...           []
# 1396220  Examining intra-rater and inter-rater response...           []
# 3126937  Comparison of ESC and ACC/AHA guidelines for m...           []
# 2923761  REL2, A Gene Encoding An Unknown Function Prot...           []
# 1516491  Microfluidic model of ductal carcinoma in situ...           []
# 868312   The natural compound Guttiferone F sensitizes ...           []
# 941425   Molecular characterisation of the STRUBBELIG-R...           []
#
#                                                 Core_Title  Len_mag  Len_core  \
# 2223095                    Everest 60 years on: what next?        3         0
# 2905384  Safety and pharmacodynamic dose response of sh...        5         0
# 3036791  Prevalence and correlates of problematic smart...       10         0
# 618489   Fish genome manipulation and directional breeding        3         0
# 1190458  The effect of reward on orienting and reorient...        2         0
# 2077065  Dynamic walking features and improved walking ...        8         0
# 3121647  Universal electronic-cigarette test: physioche...        9         0
# 2283718                     Physical Modeling of the Piano        2         0
# 1180063        Ankle morphometry in the Chinese population        7         0
# 2803267  Comparing culture and molecular methods for th...       12         0
# 2388555  Caries prevalence and impact on oral health-re...        6         0
# 2635758  The bioavailability and toxicity of ZnO and Ni...        3         0
# 876485   Iron addition as a shallow lake restoration me...        6         0
# 3536979  Early introduction of solid foods and the low ...        5         0
# 1396220  Examining intra-rater and inter-rater response...        4         0
# 3126937  Comparison of ESC and ACC/AHA guidelines for m...        4         0
# 2923761  \n                     , A Gene Encoding An Un...        8         0
# 1516491  Microfluidic model of ductal carcinoma in situ...        3         0
# 868312   The natural compound Guttiferone F sensitizes ...        7         0
# 941425   Molecular characterisation of the  of genes en...        8         0
#
#          Known_l  Known_f  Known_l_f  Known_l+f
# 2223095        0        0          0          0
# 2905384        0        0          0          0
# 3036791        0        0          0          0
# 618489         0        0          0          0
# 1190458        0        0          0          0
# 2077065        0        0          0          0
# 3121647        0        0          0          0
# 2283718        0        0          0          0
# 1180063        0        0          0          0
# 2803267        0        0          0          0
# 2388555        0        0          0          0
# 2635758        0        0          0          0
# 876485         0        0          0          0
# 3536979        0        0          0          0
# 1396220        0        0          0          0
# 3126937        0        0          0          0
# 2923761        0        0          0          0
# 1516491        0        0          0          0
# 868312         0        0          0          0
# 941425         0        0          0          0

# %%
auth_df[(auth_df.Known_l_f < auth_df.Len_mag) & (auth_df.Known_l_f < auth_df.Len_core)].sample(20)
# Out:
#              Mag_id    Core_id  \
# 844264   1989671159   44119603
# 3298522  2763674566    2448810
# 618083   1966568822   29221715
# 1242409  2030437588   11288286
# 1600344  2067190946    2366490
# 3380736    37835326  148657941
# 2145401  2130290299   79095399
# 3556169    95620398    9417703
# 1097697  2015561918   13453422
# 1425106  2049188768   20119223
# 411051   1669694821    2470423
# 958864   2001361749    2412911
# 611637   1965919202   24770637
# 620217   1966779633   42968089
# 3110754  2586352915  131165949
# 2537407  2216047827    2446251
# 1821090  2089989876   11284349
# 913574   1996770444   25955706
# 2903260  2471349610   87657852
# 58543     135436827   61421202
#
#                                                Mag_Authors  \
# 844264   [{'name': 'Vincent Revéret', 'id': '2798873930...
# 3298522       [{'name': 'J. Breitweg', 'id': '721961190'}]
# 618083   [{'name': 'Romana Novaković', 'id': '185199666...
# 1242409  [{'name': 'Claire Booth', 'id': '2120746571'},...
# 1600344  [{'name': 'Marián Boguñá', 'id': '111975288'},...
# 3380736  [{'name': 'José Antonio Calvo-Manzano Villalón...
# 2145401       [{'name': 'A. M. Bach', 'id': '2144667830'}]
# 3556169  [{'name': 'Andrew Ramsay', 'id': '2601243374'}...
# 1097697  [{'name': 'Adrian Covaci', 'id': '1814458907'}...
# 1425106  [{'name': 'Rajat Acharyya', 'id': '2163203943'...
# 411051   [{'name': 'R.B. Nevzorov', 'id': '2761600380'}...
# 958864   [{'name': 'D. Ihle', 'id': '2052766734'}, {'na...
# 611637   [{'name': 'Maria Carmen Gordillo Bargueño', 'i...
# 620217   [{'name': 'Rubén Bermejo-Poza', 'id': '2464484...
# 3110754  [{'name': 'Andrew Bosworth', 'id': '2250034292...
# 2537407  [{'name': 'S. Chekanov', 'id': '1969076968'}, ...
# 1821090  [{'name': 'Thomas Wicker', 'id': '2071793047'}...
# 913574   [{'name': 'Ivana Budic', 'id': '108526468'}, {...
# 2903260  [{'name': 'Andrés Martínez-Fernández', 'id': '...
# 58543    [{'name': 'Luis Toharia', 'id': '64618194'}, {...
#
#                                                  Mag_Title  \
# 844264   A study on the use of the PACS bolometer array...
# 3298522                  Measurement of jet shapes in high
# 618083   Micronutrient intake and status in Central and...
# 1242409  X-linked lymphoproliferative disease due to SA...
# 1600344  Cut-offs and finite size effects in scale-free...
# 3380736  CONEVTO: Contract Evaluation tool for Software...
# 2145401  Search for pair production of a new b′ quark t...
# 3556169  Sputum, sex and scanty smears: new case defini...
# 1097697  Determination of organohalogenated contaminant...
# 1425106  Income based price subsidies and parallel imports
# 411051   Renormalization of coupling constants in the m...
# 958864   MAGNETIC ORDER-DISORDER TRANSITION IN THE TWO-...
# 611637       4He adsorbed outside a single carbon nanotube
# 620217   The effect of intermittent feeding on the pre-...
# 3110754  A comparison of host gene expression signature...
# 2537407  Forward jet production in deep inelastic ep sc...
# 1821090  Frequent Gene Movement and Pseudogene Evolutio...
# 913574   The effects of different anesthesia techniques...
# 2903260  The TUCAN3G project: wireless technologies for...
# 58543                        Labour Market Studies - Spain
#
#                                               Core_Authors  \
# 844264   [Reveret, V, Rodriguez, L R, André, P, Horeau,...
# 3298522                               [ZEUS Collaboration]
# 618083   [Novakovic, R.N., Cavelaars, A.J.E.M., Bekkeri...
# 1242409  [Booth, C, Gilmour, K C, Veys, P, Gennery, A R...
# 1600344  [Boguna, Marian, Pastor-Satorras, Romualdo, Ve...
# 3380736  [Calvo-Manzano Villalon, Jose Antonio, Cuevas ...
# 2145401                     [Aad, G., ATLAS Collaboration]
# 3556169  [Ramsay, A, Bonnet, M, Gagnidze, L, Githui, W,...
# 1097697  [Covaci, Adrian, Van de Vijver, Kristin Inneke...
# 1425106        [Acharyya, Rajat, Garcia-Alonso, Maria D C]
# 411051   [Nevzorov, R. B., Ter-Martirosyan, K. A., Trus...
# 958864   [Ihle, D., Schindelin, C., Weisse, A., Fehske,...
# 611637                      [Gordillo, M. C., Boronat, J.]
# 620217   [Bermejo Poza, R., Fuente, J. de la, Pérez, C....
# 3110754  [Bosworth, A, Dowall, SD, Garcia-Dorival, I, R...
# 2537407                               [ZEUS Collaboration]
# 1821090  [Wicker, Thomas, Mayer, K F X, Gundlach, H, Ma...
# 913574   [Budić Ivana, Pavlović Dušica, Cvetković Tatja...
# 2903260  [Martínez Fernández, Andrés, Vidal Manzano, Jo...
# 58543                 [European Commission, Toharia, Luis]
#
#                                                 Core_Title  Len_mag  Len_core  \
# 844264   A study on the use of the PACS bolometer array...        7         6
# 3298522  Measurement of Jet Shapes in High-Q**2 Deep In...        1         1
# 618083   Micronutrient intake and status in Central and...       15        14
# 1242409  X-linked lymphoproliferative disease due to SA...       48        48
# 1600344  Cut-offs and finite size effects in scale-free...        3         3
# 3380736  CONEVTO: Contract Evaluation tool for Software...        5         5
# 2145401  Search for pair production of a new b′ quark t...        1         2
# 3556169  Sputum, sex and scanty smears: new case defini...        6         6
# 1097697  Determination of organohalogenated contaminant...        7         7
# 1425106  Income based price subsidies and parallel imports        2         2
# 411051   Renormalization of coupling constants in the m...        3         3
# 958864   Magnetic Order-Disorder Transition in the Two-...        4         4
# 611637       4He adsorbed outside a single carbon nanotube        2         2
# 620217   The effect of intermittent feeding on the pre-...        7         7
# 3110754  A comparison of host gene expression signature...       16        16
# 2537407  Forward jet production in deep inelastic ep sc...      329         1
# 1821090  Frequent gene movement and pseudogene evolutio...       16        17
# 913574   The effects of different anesthesia techniques...        7         7
# 2903260  The TUCAN3G project: wireless technologies for...        7         7
# 58543                        Labour Market Studies - Spain        6         2
#
#          Known_l  Known_f  Known_l_f  Known_l+f
# 844264         5        0          5          0
# 3298522        0        0          0          0
# 618083        11        0         11          0
# 1242409       46        1         47          0
# 1600344        2        2          2          2
# 3380736        3        3          4          2
# 2145401        0        0          0          0
# 3556169        5        0          5          0
# 1097697        6        4          6          4
# 1425106        1        1          1          1
# 411051         2        1          2          1
# 958864         3        3          3          3
# 611637         0        0          0          0
# 620217         5        4          6          3
# 3110754       15        0         15          0
# 2537407        0        0          0          0
# 1821090       15        2         15          2
# 913574         0        5          5          0
# 2903260        3        4          6          1
# 58543          1        1          1          1

# %%
with open(mag_path) as f:
    for i,line in enumerate(f):
        j = loads(line)
        if j['id'] == '2030437588':
            print(j)
            break
print(datetime.now())
# Out:
# {'id': '2030437588', 'title': 'X-linked lymphoproliferative disease due to SAP/SH2D1A deficiency: a multicenter study on the manifestations, management and outcome of the disease', 'authors': [{'name': 'Claire Booth', 'id': '2120746571'}, {'name': 'Kimberly Gilmour', 'id': '2892895508'}, {'name': 'Paul Veys', 'id': '2145977222'}, {'name': 'Andrew R. Gennery', 'id': '84067822'}, {'name': 'Mary Slatter', 'id': '740779825'}, {'name': 'Helen Chapel', 'id': '344128693'}, {'name': 'Paul T. Heath', 'id': '2097140458'}, {'name': 'Colin G. Steward', 'id': '2252320061'}, {'name': 'Owen P. Smith', 'id': '2130009484'}, {'name': "Anna O'Meara", 'id': '2618931660'}, {'name': 'Hilary Kerrigan', 'id': '2564349294'}, {'name': 'Nizar Mahlaoui', 'id': '314198558'}, {'name': 'Marina Cavazzana-Calvo', 'id': '2030339593'}, {'name': 'Alain Fischer', 'id': '2238277596'}, {'name': 'Despina Moshous', 'id': '51054839'}, {'name': 'Stéphane Blanche', 'id': '2224366835'}, {'name': 'Jana Pachlopnick-Schmid', 'id': '1604549289'}, {'name': 'Sylvain Latour', 'id': '1975624186'}, {'name': 'Genevieve De Saint-Basile', 'id': '2798617641'}, {'name': 'Michael H. Albert', 'id': '2133121341'}, {'name': 'Gundula Notheis', 'id': '1982203256'}, {'name': 'Nikolaus Rieber', 'id': '2070855736'}, {'name': 'Brigitte Strahm', 'id': '1976863149'}, {'name': 'Henrike Ritterbusch', 'id': '2660613466'}, {'name': 'Arjan C. Lankester', 'id': '2250256342'}, {'name': 'Nico G. Hartwig', 'id': '2192025902'}, {'name': 'Isabelle Meyts', 'id': '2164228046'}, {'name': 'Alessandro Plebani', 'id': '1402204036'}, {'name': 'Annarosa Soresina', 'id': '2015233010'}, {'name': 'Andrea Finocchi', 'id': '341157973'}, {'name': 'Claudio Pignata', 'id': '2470211229'}, {'name': 'Emilia Cirillo', 'id': '2166922622'}, {'name': 'Sonia Bonanomi', 'id': '2801694573'}, {'name': 'Christina Peters', 'id': '2181024573'}, {'name': 'Krzysztof Kałwak', 'id': '1982737143'}, {'name': 'Srdjan Pasic', 'id': '1990937767'}, {'name': 'Petr Sedlacek', 'id': '2106413369'}, {'name': 'Janez Jazbec', 'id': '2799466152'}, {'name': 'Hirokazu Kanegane', 'id': '234187042'}, {'name': 'Kim E. Nichols', 'id': '2273642418'}, {'name': 'I. Celine Hanson', 'id': '2101259837'}, {'name': 'Neena Kapoor', 'id': '2274128734'}, {'name': 'Elie Haddad', 'id': '2224123482'}, {'name': 'Morton J. Cowan', 'id': '2103767854'}, {'name': 'Sharon Choo', 'id': '2148638146'}, {'name': 'Joanne Smart', 'id': '2006108676'}, {'name': 'Peter D. Arkwright', 'id': '87578219'}, {'name': 'Hubert B. Gaspar', 'id': '2027614167'}], 'venue': {'raw': 'Blood', 'id': '200071133'}, 'year': 2011, 'n_citation': 141, 'page_start': '53', 'page_end': '62', 'doc_type': 'Journal', 'publisher': 'American Society of Hematology', 'volume': '117', 'issue': '1', 'doi': '10.1182/blood-2010-06-284935'}
# 2021-04-12 17:52:04.466658

# %% [markdown]
# We load the data generated in earlier steps of this notebook. Now we create another column which contains the number of authors between the entries matched by a Levenshtein compare of the names

# %%
import pandas as pd

auth_df = pd.read_json('results/mag_match/matching_checkup.json')

# %%
auth_df['Known_lev'] = [compare_lev(mag,core) for mag, core in zip(auth_df['Mag_Authors'],auth_df['Core_Authors'])]

# %%
auth_df
# Out:
#              Mag_id   Core_id  \
# 0        1000000185  42023535
# 1         100000407  82235102
# 2        1000007777   9554974
# 3        1000013286  36706632
# 4        1000014399   6112882
# ...             ...       ...
# 3567226   999972508  82484073
# 3567227    99997835  82317676
# 3567228   999981119  18590244
# 3567229   999981997  31012454
# 3567230    99998370  25279111
#
#                                                Mag_Authors  \
# 0            [{'name': 'Sanpei Usui', 'id': '2398577680'}]
# 1        [{'name': 'Surender Deora', 'id': '2132854008'...
# 2        [{'name': 'Shengye Zeng', 'id': '2163875822'},...
# 3        [{'name': 'Clifford Allison. Rose', 'id': '251...
# 4        [{'name': 'Nicky Stanley', 'id': '2171225193'}...
# ...                                                    ...
# 3567226  [{'name': 'Rebecca A. Fischer', 'id': '2164566...
# 3567227  [{'name': 'Alice K. Jacobs', 'id': '2807342118'}]
# 3567228          [{'name': 'Zhe Kan', 'id': '2649816162'}]
# 3567229  [{'name': 'Georg Futter', 'id': '2124207548'},...
# 3567230  [{'name': 'A P De Haas', 'id': '2791063430'}, ...
#
#                                                  Mag_Title  \
# 0        Complex structures on partial compactification...
# 1        Cardiac Epithelioid Leiomyosarcoma as Both Int...
# 2        The investigation of material removal in bonne...
# 3        Time multiplexing of compensation in control s...
# 4        Disclosing Disability: Disabled students and p...
# ...                                                    ...
# 3567226  High pressure metal–silicate partitioning of N...
# 3567227  Women, ischemic heart disease, revascularizati...
# 3567228  Electrical properties of carbon structures : c...
# 3567229  Modeling of transport and degradation processe...
# 3567230  Very low mass microcables for the ALICE silico...
#
#                                               Core_Authors  \
# 0                                           [Usui, Sanpei]
# 1        [Deora, Surender, Gurmukhani, Sunil, Shah, San...
# 2               [Zeng, Shengye, Blunt, Liam, Jiang, Xiang]
# 3                                [Rose, Clifford Allison.]
# 4        [Stanley, Nicky, Ridley, Julie, Harris, Jessic...
# ...                                                    ...
# 3567226  [Fischer, Rebecca A., Nakajima, Yoichi, Campbe...
# 3567227                                 [Jacobs, Alice K.]
# 3567228                                         [Kan, Zhe]
# 3567229      [Futter, Georg, Jahnke, Thomas, Latz, Arnulf]
# 3567230  [De Haas, A P, Oskamp, C J, Van den Brink, A, ...
#
#                                                 Core_Title  Len_mag  Len_core  \
# 0        Complex structures on partial compactification...        1         1
# 1        Cardiac Epithelioid Leiomyosarcoma as Both Int...        6         6
# 2        The investigation of material removal in bonne...        3         3
# 3        Time multiplexing of compensation in control s...        1         1
# 4        Disclosing Disability: Disabled students and p...        5         5
# ...                                                    ...      ...       ...
# 3567226  High pressure metal–silicate partitioning of N...        9         9
# 3567227  Women, Ischemic Heart Disease, Revascularizati...        1         1
# 3567228  Electrical properties of carbon structures : c...        1         1
# 3567229  Modeling of transport and degradation processe...        3         3
# 3567230  Very low mass microcables for the ALICE silico...        7         7
#
#          Known_l  Known_f  Known_l_f  Known_l+f  Known_lev
# 0              1        1          1          1          1
# 1              8        6          8          6          6
# 2              3        3          3          3          3
# 3              1        1          1          1          1
# 4              5        5          5          5          5
# ...          ...      ...        ...        ...        ...
# 3567226        9        9          9          9          9
# 3567227        1        1          1          1          1
# 3567228        1        1          1          1          1
# 3567229        3        3          3          3          3
# 3567230        7       12         15          4          7
#
# [3567231 rows x 13 columns]

# %%
auth_df[auth_df.Known_lev == 0]
# Out:
#              Mag_id    Core_id  \
# 53       1000214280   82394347
# 57       1000229741   81870759
# 152      1000581368   82342819
# 187       100073140  143779951
# 346       100140187   15158514
# ...             ...        ...
# 3566783   998266863   81891020
# 3566873   998676226   81529672
# 3566943    99898334   81734742
# 3566991    99917349   81067737
# 3567028    99930091   81707665
#
#                                                Mag_Authors  \
# 53       [{'name': 'Virtue Registry Investigators', 'id...
# 57       [{'name': 'Monika Riegel', 'id': '1968574148'}...
# 152        [{'name': 'İsmail Bircan', 'id': '2314037064'}]
# 187      [{'name': 'Suzanne Elanore Turner Murray', 'id...
# 346      [{'name': 'W. G. H. Maxwell', 'id': '213743812...
# ...                                                    ...
# 3566783  [{'name': 'Christian Ritzer', 'id': '241427995...
# 3566873  [{'name': 'Mpho Keetile', 'id': '87376778'}, {...
# 3566943  [{'name': 'Paula Tuma', 'id': '2293251928'}, {...
# 3566991  [{'name': 'Zhenlong Liu', 'id': '2105551457'},...
# 3567028  [{'name': 'Stanislas Rapacchi', 'id': '2039806...
#
#                                                  Mag_Title  \
# 53       Mid-term outcomes and aortic remodelling after...
# 57       Characterization of the Nencki Affective Pictu...
# 152      Analysis of Innovation-Based Human Resources f...
# 187      A comparison of some computational techniques ...
# 346      Upper Palaeozoic formations in the Mt. Morgan ...
# ...                                                    ...
# 3566783  Measurement of the point spread function of a ...
# 3566873  Patterns and determinants of hypertension in B...
# 3566943  Outcome of chronic hepatitis delta in patients...
# 3566991  The interferon-induced MxB protein inhibits an...
# 3567028  High spatial and temporal resolution dynamic c...
#
#                                               Core_Authors  \
# 53                                                      []
# 57                                                      []
# 152                       [Bircan, İsmail, Gençler, Funda]
# 187      [Murray, Suzanne Elanore Turner, 1940-, Murray...
# 346         [Maxwell, W. G. H. (William Graham Henderson)]
# ...                                                    ...
# 3566783                                                 []
# 3566873                                                 []
# 3566943                                                 []
# 3566991                                                 []
# 3567028                                                 []
#
#                                                 Core_Title  Len_mag  Len_core  \
# 53       Mid-term Outcomes and Aortic Remodelling After...        1         0
# 57       Characterization of the Nencki Affective Pictu...       13         0
# 152      Analysis of Innovation-Based Human Resources f...        1         2
# 187      A comparison of some computational techniques ...        1         2
# 346      Upper Palaeozoic formations in the Mt. Morgan ...        1         1
# ...                                                    ...      ...       ...
# 3566783  Measurement of the point spread function of a ...        4         0
# 3566873  Patterns and determinants of hypertension in B...        3         0
# 3566943  Outcome of chronic hepatitis delta in patients...        9         0
# 3566991  The interferon-induced MxB protein inhibits an...        8         0
# 3567028  High spatial and temporal resolution dynamic c...       10         0
#
#          Known_l  Known_f  Known_l_f  Known_l+f  Known_lev
# 53             0        0          0          0          0
# 57             0        0          0          0          0
# 152            1        1          1          1          0
# 187            2        2          2          2          0
# 346            1        1          1          1          0
# ...          ...      ...        ...        ...        ...
# 3566783        0        0          0          0          0
# 3566873        0        0          0          0          0
# 3566943        0        0          0          0          0
# 3566991        0        0          0          0          0
# 3567028        0        0          0          0          0
#
# [182517 rows x 13 columns]

# %%
auth_df[(auth_df.Known_lev < auth_df.Len_mag) & (auth_df.Known_lev < auth_df.Len_core)]
# Out:
#              Mag_id    Core_id  \
# 152      1000581368   82342819
# 187       100073140  143779951
# 199       100079032   12356592
# 255       100103939   16388691
# 305       100120857   20342195
# ...             ...        ...
# 3567016   999271521   33667039
# 3567096   999549861   82522043
# 3567148   999726932   36088314
# 3567195   999883381   36047224
# 3567196   999892512   81171909
#
#                                                Mag_Authors  \
# 152        [{'name': 'İsmail Bircan', 'id': '2314037064'}]
# 187      [{'name': 'Suzanne Elanore Turner Murray', 'id...
# 199      [{'name': 'O. O. Ajayi', 'id': '2470271829'}, ...
# 255      [{'name': 'Ryota Nakajima', 'id': '2099235777'...
# 305      [{'name': 'Marta Luna Serrano', 'id': '2104771...
# ...                                                    ...
# 3567016  [{'name': 'Saskia Brix', 'id': '2048068937'}, ...
# 3567096  [{'name': 'Andrea Sujová', 'id': '2310056901'}...
# 3567148  [{'name': 'Irene Gonzalez-Valls', 'id': '20322...
# 3567195  [{'name': 'Pelayo González', 'id': '2175088314...
# 3567196  [{'name': 'Pranas Baltrenas', 'id': '226744247...
#
#                                                  Mag_Title  \
# 152      Analysis of Innovation-Based Human Resources f...
# 187      A comparison of some computational techniques ...
# 199      Assessment of Wind Power Potential and Wind El...
# 255      Sedimentation impacts on the growth rates of t...
# 305      Dysfunctional 3D model based on structural and...
# ...                                                    ...
# 3567016  IceAGE - Icelandic marine Animals: Genetics an...
# 3567096  Modern Methods of Process Management Used in S...
# 3567148  Aligned semiconductor oxide nanostructures for...
# 3567195  Functional polymorphism in the promoter region...
# 3567196  Experimental Research of Odours Arising During...
#
#                                               Core_Authors  \
# 152                       [Bircan, İsmail, Gençler, Funda]
# 187      [Murray, Suzanne Elanore Turner, 1940-, Murray...
# 199           [Ajayi, O. O., Fagbenle, R. O., Katende, J.]
# 255      [R., Nakajima, T., Yoshida, Y., Fuchinove, T.,...
# 305      [Luna Serrano, Marta, Caballero Hernandez, Rut...
# ...                                                    ...
# 3567016  [Brix, Saskia, Martinez, Pedro, Svavarsson, Jö...
# 3567096            [Sujova, Andrea, Marcinekova, Katarina]
# 3567148  [González-Valls, Irene, González-García, Lola,...
# 3567195  [González, P., Díez-Juan, Antonio, Andrés, Vic...
# 3567196  [Baltrenas, Pranas, Misevicius, Antonas, Macai...
#
#                                                 Core_Title  Len_mag  Len_core  \
# 152      Analysis of Innovation-Based Human Resources f...        1         2
# 187      A comparison of some computational techniques ...        1         2
# 199      Assessment of Wind Power Potential and Wind El...        3         3
# 255      Sedimentation impacts on the growth rates of t...        8         8
# 305      Dysfunctional 3D model based on structural and...       10        10
# ...                                                    ...      ...       ...
# 3567016  IceAGE - Icelandic marine Animals: Genetics an...       11        11
# 3567096  Modern Methods of Process Management Used in S...        2         2
# 3567148  Aligned semiconductor oxide nanostructures for...        8         8
# 3567195  Functional polymorphism in the promoter region...        5         5
# 3567196  Experimental Research of Odours Arising During...        4         4
#
#          Known_l  Known_f  Known_l_f  Known_l+f  Known_lev
# 152            1        1          1          1          0
# 187            2        2          2          2          0
# 199            2        3          3          2          2
# 255            7        9         13          3          7
# 305            9       12         12          9          9
# ...          ...      ...        ...        ...        ...
# 3567016       10       11         11         10         10
# 3567096        0        1          1          0          1
# 3567148        6        6          7          5          7
# 3567195        4        4          5          3          4
# 3567196        2        3          3          2          2
#
# [158835 rows x 13 columns]

# %%
auth_df[(auth_df.Known_lev < auth_df.Len_mag) & (auth_df.Known_lev < auth_df.Len_core)].sample(20)
# Out:
#              Mag_id   Core_id  \
# 3078091  2566879760  93347338
# 395629   2578560219  16293427
# 1001203  2005719012  13736463
# 1072011  2012946639  62456001
# 2974136  2519659746  74658331
# 1133593  2019229259  50691874
# 2179515  2749636074  85125898
# 572470   1942594925  81144151
# 943928   1999845618  13718277
# 800717   1985252301  13733564
# 2900688  2470224302  77928090
# 2616576  2260014832   4396510
# 675522   1972437527  16206235
# 1974610  2108356100  52115955
# 3023447  2538817542  18322840
# 966820   2002182753  35082725
# 2547697  2223342322  50568880
# 482698   1818498346  80178685
# 1370657  2043577581  82811044
# 1127303  2018585843  82476056
#
#                                                Mag_Authors  \
# 3078091  [{'name': 'Sebastian Dullien', 'id': '20374438...
# 395629   [{'name': 'Piotr S. Żuchowski', 'id': '2590333...
# 1001203  [{'name': 'Anders Falk Vikbjerg', 'id': '20252...
# 1072011  [{'name': 'Acilina Caneco', 'id': '289769456'}...
# 2974136  [{'name': 'Thomas De Schryver', 'id': '2194005...
# 1133593  [{'name': 'Henrik Hein Lauridsen', 'id': '2058...
# 2179515  [{'name': 'Suraj Peri', 'id': '2016816938'}, {...
# 572470   [{'name': 'William W. Hope', 'id': '2096597877...
# 943928   [{'name': 'C. B. Collins', 'id': '2155199751'}...
# 800717   [{'name': 'Mads Brandbyge', 'id': '2462294175'...
# 2900688  [{'name': 'Karl Forster', 'id': '2167516218'},...
# 2616576  [{'name': 'Brian J. Friedlich', 'id': '2262880...
# 675522   [{'name': 'M. Fernandez', 'id': '2439006305'},...
# 1974610  [{'name': 'Vesna Boraska', 'id': '27725982'}, ...
# 3023447  [{'name': 'Arnau Rios', 'id': '2129517039'}, {...
# 966820   [{'name': 'Aldo Deandrea', 'id': '2082655632'}...
# 2547697  [{'name': 'Zoltan Lohinai', 'id': '2393519140'...
# 482698   [{'name': 'Lucian Farcal', 'id': '2233232944'}...
# 1370657  [{'name': 'Salvador Arlandis', 'id': '27112420...
# 1127303  [{'name': 'Karoly Urmossy', 'id': '2461172761'...
#
#                                                  Mag_Title  \
# 3078091  The IMF to the rescue: Did the euro area benef...
# 395629   Low-energy collisions ofNH3andND3with ultracol...
# 1001203  Synthesis of structured phospholipids by immob...
# 1072011   Kneading theory analysis of the Duffing equation
# 2974136  In-line NDT with X-Ray CT combining sample rot...
# 1133593       Development of the young spine questionnaire
# 2179515  Development of human protein reference databas...
# 572470   EUCAST Technical Note on Voriconazole and Aspe...
# 943928   Microstructural analyses of amorphic diamond, ...
# 800717   Density-functional method for nonequilibrium e...
# 2900688   Getting NuSTAR on target: predicting mast motion
# 2616576  Low-impact development in the Assabet River Wa...
# 675522   Heat pulse line‐source method to determine the...
# 1974610  A genome-wide association study of anorexia ne...
# 3023447  Self-consistent Green's functions calculation ...
# 966820                               Multi-tops at the LHC
# 2547697  From bench to bedside: Attempt to evaluate rep...
# 482698   Comprehensive in vitro toxicity testing of a p...
# 1370657  PUK12 CLINICAL AND ECONOMIC EVALUATION OF OVER...
# 1127303  Microcanonical jet-fragmentation in proton–pro...
#
#                                               Core_Authors  \
# 3078091  [Dullien, Sebastian, Fritz, Barbara, M\ufchlic...
# 395629          [Zuchowski,  Piotr S., Hutson,  Jeremy M.]
# 1001203  [Vikbjerg, Anders Falk, Vikbjerg, Anders Falk,...
# 1072011      [Caneco, Acilina, Rocha, Jose, Gracio, Clara]
# 2974136  [De Schryver, Thomas, Dhaene, Jelle, Dierick, ...
# 1133593            [Lauridsen, Henrik Hein, Hestbæk, Lise]
# 2179515  [Peri, Suraj, Navarro, J.Daniel, Amanchy, Rama...
# 572470   [Hope, W.W., Cuenca-Estrella, M., Lass-Florl, ...
# 943928   [Collins, C. B., Davanloo, F., Jander, D.R., L...
# 800717   [Brandbyge, Mads, Mozos, J.L., Ordejon, P., Ta...
# 2900688  [Foster, Karl, Madsen, Kristin K., Miyasaka, H...
# 2616576        [Friedlich, Brian J. (Brian Joseph), 1982-]
# 675522   [Fernández i Ortiga, Manel, Banda, E. (Enric),...
# 1974610  [Reichborn-Kjennerud, Ted, Knudsen, Gun Peggy,...
# 3023447                                 [Rios, A, Soma, V]
# 966820   [Aldo DeandreaUniversité de Lyon, France, Nico...
# 2547697  [Lohinai, Zoltán, Döme, Péter, Szilagyi Z, Ost...
# 482698   [Farcal, L, Andon, Ft, Di Cristo, L, Rotoli, B...
# 1370657  [Arlandis, S, Castro, D, Errando, C, Fernandez...
# 1127303        [Urmossy, K., Barnaföldi, G.G., Biró, T.S.]
#
#                                                 Core_Title  Len_mag  Len_core  \
# 3078091  The IMF to the rescue: Did the euro area benef...        3         3
# 395629   Low-energy collisions of NH3 and ND3 with ultr...        2         2
# 1001203  Synthesis of structured phospholipids by immob...        3         3
# 1072011   Kneading theory analysis of the Duffing equation        3         3
# 2974136  In-line NDT with X-Ray CT combining sample rot...       10        10
# 1133593       Development of the young spine questionnaire        2         2
# 2179515  Development of human protein reference databas...       50        50
# 572470   EUCAST Technical Note on Voriconazole and Aspe...        4         4
# 943928   Microstructural analyses of amorphic diamond, ...        9         9
# 800717   Density-functional method for nonequilibrium e...        5         5
# 2900688   Getting NuSTAR on target: predicting mast motion        8         8
# 2616576  Low-impact development in the Assabet River Wa...        1         1
# 675522   Heat pulse line-source method to determine the...        3         3
# 1974610  A genome-wide association study of anorexia ne...       73        50
# 3023447  Self-consistent Green's functions calculation ...        2         2
# 966820                               Multi-tops at the LHC        3         2
# 2547697  From Bench to Bedside: Attempt to Evaluate Rep...        9         8
# 482698   Comprehensive in vitro toxicity testing of a p...       30        30
# 1370657  PUK12 CLINICAL AND ECONOMIC EVALUATION OF OVER...       10        10
# 1127303  Microcanonical jet-fragmentation in proton–pro...        3         3
#
#          Known_l  Known_f  Known_l_f  Known_l+f  Known_lev
# 3078091        2        3          3          2          2
# 395629         1        2          2          1          1
# 1001203        3        3          3          3          2
# 1072011        2        2          3          1          2
# 2974136        9       11         11          9          9
# 1133593        1        2          2          1          1
# 2179515       52       65         69         48         49
# 572470         3        0          3          0          3
# 943928         8        8         10          6          8
# 800717         4        3          4          3          4
# 2900688        8        8         10          6          7
# 2616576        1        1          1          1          0
# 675522         2        2          3          1          2
# 1974610        9      270        274          5          9
# 3023447        1        1          2          0          1
# 966820         3        3          3          3          0
# 2547697        5        1          5          1          5
# 482698        32        0         32          0         29
# 1370657        9       15         20          4          9
# 1127303        2        1          2          1          2

# %%
def authors_full(id):
    print(auth_df.loc[id].Mag_Authors)
    print('\n')
    print(auth_df.loc[id].Core_Authors)

# %%
authors_full(3567196)
# Out:
# [{'name': 'Pranas Baltrenas', 'id': '2267442476'}, {'name': 'Antonas Misevičius', 'id': '2506408229'}, {'name': 'Kęstutis Mačaitis', 'id': '2313707204'}, {'name': 'Ruta Tekoriene', 'id': '2607635964'}]
#
#
# ['Baltrenas, Pranas', 'Misevicius, Antonas', 'Macaitis, Kestutis', 'Tekoriene, Ruta']

# %%
authors_full(3567148)
# Out:
# [{'name': 'Irene Gonzalez-Valls', 'id': '2032253405'}, {'name': 'Lola González-García', 'id': '2023463444'}, {'name': 'Belén Ballesteros', 'id': '2106546204'}, {'name': 'F. Güell', 'id': '2343592621'}, {'name': 'Angel Barranco', 'id': '2133005086'}, {'name': 'Youhai Yu', 'id': '2105708633'}, {'name': 'Agustín R. González-Elipe', 'id': '1956032063'}, {'name': 'Monica Lira-Cantu', 'id': '2006387408'}]
#
#
# ['González-Valls, Irene', 'González-García, Lola', 'Ballesteros, Belén', 'Güell, F.', 'Barranco, Ángel', 'Yu, Youhai', 'González-Elipe, Agustín R.', 'Lira-Cantú, Mónica']

# %% [markdown]
# ### After comparing authorlists of matched articles by a variety of measures, differences in the lists could be found for around 158K entries out of 3.5M. No clear mismatch was found.
